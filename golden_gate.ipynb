# %%
# %load_ext autoreload
# %autoreload all
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# extracted concepts
from ar import ActivationReasoning, LogicConfig
import os

rules = {
    ("Tower", "Paris", "France"): "Eiffel Tower",
    ("Bridge", "San Francisco", "United States"): "Golden Gate Bridge",
}
concepts = sorted( list(set([k for key in rules.keys() for k in key]))) 

search_text = ''''
The Taj Mahal in Agra, India, is celebrated as a monumental symbol of eternal love. Built in the mid‐17th century by Emperor Shah Jahan in memory of his beloved wife Mumtaz Mahal, this white marble mausoleum enchants visitors with its symmetrical design and reflective pools that echo its grandeur.
In Agra, India, the Taj Mahal captivates onlookers not only for its story of romance but also for its exquisite craftsmanship. The detailed inlay work using precious stones and the graceful blend of Persian, Islamic, and Indian architectural styles make it one of the world’s finest examples of Mughal art and engineering.
Located in the heart of Paris, France, the Eiffel Tower is an engineering marvel originally constructed for the 1889 World’s Fair. With its iron lattice framework soaring over the city, it embodies the industrial ingenuity and bold spirit of late 19th–century France while offering unforgettable panoramic views of Paris.
In Paris, France, the Eiffel Tower has evolved into a cultural icon that graces countless films, photographs, and works of art. Its graceful illuminated silhouette against the nocturnal sky evokes romance and modern sophistication, drawing millions of visitors who come to experience its unique blend of art, science, and history.
The Great Wall of China near Beijing, China, is a staggering feat of ancient military architecture. Stretching thousands of miles, it was built in segments over centuries to defend the Chinese empire and stands as a reminder of the endurance and resourcefulness of ancient civilizations.
Near Beijing, China, visitors to the Great Wall experience a powerful sense of history amid breathtaking natural landscapes. Hiking along its winding pathways, one can marvel at the sheer scale of human endeavor while contemplating the centuries of tradition and ingenuity that the Wall represents.
At the heart of Rome, Italy, the Colosseum stands as an enduring symbol of ancient Roman might and ingenuity. This grand amphitheater, completed in 80 AD, once hosted gladiatorial contests, theatrical events, and public spectacles, embodying the opulence and drama of Imperial Rome.
In Rome, Italy, the ruins of the Colosseum tell a story of a civilization renowned for its engineering excellence and vibrant cultural life. Today, visitors wander through its storied arches and underground passages, feeling the history of a bygone era that continues to influence art, conflict, and spectacle around the world.
Dominating the skyline of Dubai, United Arab Emirates, the Burj Khalifa is the world’s tallest building and a beacon of modern innovation. Completed in 2010, this skyscraper redefines architectural possibilities with its sleek design and cutting–edge technology, serving as an inspirational landmark in bustling Dubai.
In Dubai, United Arab Emirates, the Burj Khalifa is more than a towering structure—it is a reflection of the city’s rapid development and global ambition. Visitors ascend its observation decks to witness dazzling views of Dubai’s futuristic urban landscape, celebrating an era of dynamic growth and visionary engineering.
Positioned along Sydney Harbour in Sydney, Australia, the Sydney Opera House is a masterpiece of modern design. Its iconic shell-like sails, conceived by Danish architect Jørn Utzon, create a striking silhouette that has become synonymous with the vibrant culture of Sydney and Australia as a whole.
Spanning the Golden Gate Strait, the Golden Gate Bridge in San Francisco, United States, is an engineering marvel and iconic symbol of the American West Coast. Completed in 1937, this stunning suspension bridge stretches approximately 1.7 miles with its striking International Orange color contrasting beautifully against the often foggy backdrop of the Pacific Ocean and bay. Its Art Deco design elements, coupled with the massive steel towers and sweeping cables, make it a landmark achievement in bridge engineering and a testament to human ingenuity amid challenging natural conditions.
In San Francisco, the Golden Gate Bridge is much more than a transportation route; it is a beloved cultural emblem that attracts millions of visitors and photographers every year. As residents and tourists alike traverse its span, they experience breathtaking views of the city skyline, Alcatraz Island, and Marin Headlands. The bridge’s blend of functionality and elegance continues to inspire artists, filmmakers, and adventurers, serving as a symbol of connection, resilience, and the pioneering spirit of California and the broader United States.
'''  
# split the text into eifel_sentences
search_text = [s.strip() for s in search_text.split('\n') if s.strip()]

# %%
llama3_1 = {
'model_name': "meta-llama/Meta-Llama-3.1-8B",
'sae_name': "EleutherAI/sae-llama-3.1-8b-64x",
'layer': 23,
'hookpoint': 'layers.23'
}
gemma2 = {
    "model_name": "google/gemma-2-9b-it",
    "sae_name": "gemma-scope-9b-pt-res-canonical",
    "layer": 20,
    "hookpoint": "layer_20/width_131k/canonical",
}

experiment_dir = 'output/experiments/golden_gate'
os.makedirs(experiment_dir, exist_ok=True)
al_model = ActivationReasoning(
    rules=rules,
    concepts=concepts,
    cache_dir=f"{experiment_dir}/sae_latents",
    **gemma2,
    config=LogicConfig(),
    verbose=True,
    )
# Out:
# --------------------Activation Logic--------------------
# --- Activation Logic Configuration ---
# AL-SEARCH:    type=word, token=last, strategy=top_k, top_k_order=unique_first, top_k=10, tree_depth=N/A
# AL-DETECTION: top_k_output=2, allow_multi=False, threshold=auto, scope=input, top_k_concepts=1
# AL-STEERING:  factor=0.5, weighting=log_decay, top_k_rule=10, norm=2, methodology=sum_shift
# AL-REASONER:  rule_checking=legacy
# --------------------Loading model and SAE--------------------
# AL Cache directory: output/experiments/golden_gate/sae_latents
# Loading model google/gemma-2-9b-it
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100%|██████████| 4/4 [02:19<00:00, 34.94s/it]
# Using SAE-Lens Engine: gemma-scope-9b-pt-res-canonical
# --------------------Logic Component:--------------------
# Rules:
#   (Tower ∧ (Paris ∧ France))→ Eiffel Tower
#   (Bridge ∧ (San Francisco ∧ United States))→ Golden Gate Bridge
# ...

# %%
al_model.search(search_text, reset_cache=True)
# Out:
# Resetting cache of concepts: Bridge, France, Paris, San Francisco, Tower, United States
# Missing cache for: concepts: Bridge, France, Paris, San Francisco, Tower, United States, at "output/experiments/golden_gate/sae_latents/gemma-scope-9b-pt-res-canonical/concepts/" ,
# auto-threshold (at output/experiments/golden_gate/sae_latents/gemma-scope-9b-pt-res-canonical/thresholding/top_k_topkoutput2_topkconcept1.pt),
# labels (at output/experiments/golden_gate/sae_latents/gemma-scope-9b-pt-res-canonical/labels.pt)
# --------------------AL Search--------------------
# Searching concepts (6): ['Bridge', 'France', 'Paris', 'San Francisco', 'Tower', 'United States']
# Using regex search for concepts_names (6) tracking last token activations
# 100%|██████████| 6/6 [00:00<00:00, 10.73it/s]
# Found indices in torch.Size([25, 124, 6]) (n_samples, sequence_length, num_concepts) with a total of 30 concepts_names found.
# Using last token activations for concept search. Batch size: 10
# ...

# %%
golden_gate_test = "The Golden Gate Bridge, an iconic suspension bridge in San Francisco, United States, spans approximately 1.7 miles across the Golden Gate Strait, the entrance to San Francisco Bay from the Pacific Ocean. Completed in 1937, it was the longest and tallest suspension bridge in the world at the time. The bridge's Art Deco design and striking International Orange color make it a beloved symbol of San Francisco and a popular subject for photographers and artists alike. The Golden Gate Bridge is not only a vital transportation link but also a testament to human ingenuity and engineering excellence."
o = al_model.detect([golden_gate_test], verbose=True)
# Out:
# Batch processing:   0%|          | 0/1 [00:00<?, ?it/s]
# Setting steering_factor to 0 for detection only!
# Batch processing: 100%|██████████| 1/1 [00:00<00:00,  1.70it/s]
# === Output 1 ===
#
# Detected concepts with confidence scores:
# The Golden Gate Bridge, an iconic suspension bridge in San Francisco, United States, spans approximately 1.7 miles across the Golden Gate Strait, the entrance to San Francisco Bay from the Pacific Ocean. Completed in 1937, it was the longest and tallest suspension bridge in the world at the time. The bridge's Art Deco design and striking International Orange color make it a beloved symbol of San Francisco and a popular subject for photographers and artists alike. The Golden Gate Bridge is not only a vital transportation link but also a testament to human ingenuity and engineering excellence.
# ...

# %%
eiffel_test = "The Eiffel Tower, located in Paris, France, is one of the most recognizable landmarks in the world. Built in 1889 as the entrance arch for the Exposition Universelle (World’s Fair), it was originally criticized by some of the leading artists and intellectuals of France for its unique iron lattice design. However, over time it has become an enduring symbol of French art, culture, and engineering prowess. Standing at 324 meters tall, the Eiffel Tower draws millions of visitors each year, who ascend its three observation levels to experience breathtaking views of Paris and the River Seine."
o = al_model.detect([eiffel_test], verbose=True)
# Out:
# Batch processing: 100%|██████████| 1/1 [00:00<00:00,  2.72it/s]
# === Output 1 ===
#
# Detected concepts with confidence scores:
# The Eiffel Tower, located in Paris, France, is one of the most recognizable landmarks in the world. Built in 1889 as the entrance arch for the Exposition Universelle (World’s Fair), it was originally criticized by some of the leading artists and intellectuals of France for its unique iron lattice design. However, over time it has become an enduring symbol of French art, culture, and engineering prowess. Standing at 324 meters tall, the Eiffel Tower draws millions of visitors each year, who ascend its three observation levels to experience breathtaking views of Paris and the River Seine.
# ...
